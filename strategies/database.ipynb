# %%
import sqlite3

# Path to your database file in the db folder
db_path = "../db/openalgo.db"  # Replace with the actual database file name

# Connect to the database
conn = sqlite3.connect(db_path)

# Query to list all tables
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()

# Print the tables
print("Tables in the database:")
for table in tables:
    print(table[0])

# Close the connection
conn.close()
# Out:
# Tables in the database:
# auth
# api_keys
# users
# symtoken
# order_logs
# analyzer_logs
# settings
# chartink_strategies
# chartink_symbol_mappings
# strategies
# strategy_symbol_mappings

# %%
import sqlite3
import pandas as pd



# Connect to the database
conn = sqlite3.connect(db_path)


# Preview data from a specific table
df = pd.read_sql_query("SELECT * FROM order_logs LIMIT 10;", conn)  # Replace 'your_table' with actual table name
df
# Out:
#    id    api_type                                       request_data  \
# 0   1  placeorder  {"strategy": "Period_Range_Breakout_V2_IST", "...
# 1   2  placeorder  {"strategy": "Period_Range_Breakout_V2_IST", "...
# 2   3  placeorder  {"strategy": "Period_Range_Breakout_V2_IST", "...
# 3   4  placeorder  {"strategy": "Period_Range_Breakout_V2_IST", "...
# 4   5  placeorder  {"strategy": "Period_Range_Breakout_V2_IST", "...
# 5   6  placeorder  {"strategy": "Period_Range_Breakout_V2_IST", "...
# 6   7  placeorder  {"strategy": "Period_Range_Breakout_V2_IST", "...
# 7   8  placeorder  {"strategy": "Period_Range_Breakout_V2_IST", "...
# 8   9  placeorder  {"strategy": "Period_Range_Breakout_V2_IST", "...
# 9  10  placeorder  {"strategy": "Period_Range_Breakout_V2_IST", "...
#
#                                        response_data  \
# 0  {"status": "success", "orderid": "250519000313...
# 1  {"status": "success", "orderid": "250519000334...
# ...

# %%
# Close the connection
conn.close()
