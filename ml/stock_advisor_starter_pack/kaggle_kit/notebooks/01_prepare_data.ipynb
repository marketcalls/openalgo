# %% [markdown]
# # 01 Prepare Data
#
# Read Excel or CSV inputs, normalize columns, convert timestamps, filter Indian session hours, and save clean Parquet files.

# %%
import pandas as pd
from pathlib import Path

INPUT_ROOT = Path('/kaggle/input/your-dataset/market_data')
WORKING_ROOT = Path('/kaggle/working/prepared_data')
WORKING_ROOT.mkdir(parents=True, exist_ok=True)

# TODO: load raw sheets/files, normalize to canonical schema, and export parquet files.
