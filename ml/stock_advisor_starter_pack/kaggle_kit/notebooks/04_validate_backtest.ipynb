# %% [markdown]
# # 04 Validate Backtest
#
# Run walk-forward validation, compare candidate versus baseline strategies, and assemble holdout metrics.

# %%
from pathlib import Path

MODEL_ROOT = Path('/kaggle/working/models')
REPORT_ROOT = Path('/kaggle/working/reports')
REPORT_ROOT.mkdir(parents=True, exist_ok=True)

# TODO: evaluate trained bundles, save validation CSVs, and create promotion summaries.
