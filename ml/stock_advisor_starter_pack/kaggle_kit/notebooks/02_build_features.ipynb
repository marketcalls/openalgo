# %% [markdown]
# # 02 Build Features
#
# Load cleaned OHLCV files, run strategy wrappers, align higher timeframes, and save feature tables.

# %%
from pathlib import Path

PREPARED_ROOT = Path('/kaggle/working/prepared_data')
FEATURE_ROOT = Path('/kaggle/working/features')
FEATURE_ROOT.mkdir(parents=True, exist_ok=True)

# TODO: build strategy and regime features per symbol and horizon.
