# %% [markdown]
# # 05 Export Bundle
#
# Copy the approved candidate bundle and summary reports into `/kaggle/working/exports` for download.

# %%
from pathlib import Path

EXPORT_ROOT = Path('/kaggle/working/exports')
EXPORT_ROOT.mkdir(parents=True, exist_ok=True)

# TODO: package the selected bundle, reports, and feature schema for download.
