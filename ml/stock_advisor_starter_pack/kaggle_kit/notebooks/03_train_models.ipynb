# %% [markdown]
# # 03 Train Models
#
# Train the regime classifier, setup ranker, and confidence calibrator on chronological splits.

# %%
from pathlib import Path

FEATURE_ROOT = Path('/kaggle/working/features')
MODEL_ROOT = Path('/kaggle/working/models')
MODEL_ROOT.mkdir(parents=True, exist_ok=True)

# TODO: train candidate bundles and save metadata, objects, and reports.
